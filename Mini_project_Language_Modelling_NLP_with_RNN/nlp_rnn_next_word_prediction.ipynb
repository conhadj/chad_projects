# %%
import numpy as np
import torch
import torch.nn.functional as torchFunctional
import sys

# %%
input_string = [2, 45, 30, 55, 10]
output_string = [45, 30, 55, 10, 1]

# %%
num_features = 100 #number of features of our embeddings
vocab_size = 80

# %%
embeddings = list()
for i in range(len(input_string)):
  x = np.random.randn(num_features, 1)
  embeddings.append(x)

# %%
embeddings[0].shape
# Out:
# (100, 1)

# %%
len(embeddings)
# Out:
# 5

# %%
def get_one_hot(idx):
  one_hot = np.zeros((vocab_size, 1))
  one_hot[idx] = 1
  return one_hot

# %%
num_units = 50
h0 = torch.tensor(np.zeros((num_units, 1)))
Wh = torch.tensor(np.random.uniform(0, 1, (num_units, num_units)), requires_grad=True)
Wx = torch.tensor(np.random.uniform(0, 1, (num_units, num_features)), requires_grad=True)
Wy = torch.tensor(np.random.uniform(0, 1, (vocab_size, num_units)), requires_grad=True)

# %%
print(Wh.shape, Wx.shape, Wh.shape, h0.shape)
# Out:
# torch.Size([50, 50]) torch.Size([50, 100]) torch.Size([50, 50]) torch.Size([50, 1])

# %%
def stepForward(xt, Wx, Wh, Wy, prev_memory):
  x_frwrd = torch.matmul(Wx, torch.from_numpy(xt))
  h_frwrd = torch.matmul(Wh, prev_memory)
  ht = torch.tanh(x_frwrd + h_frwrd)
  yt_hat = torchFunctional.softmax(torch.matmul(Wy, ht), dim = 0)
  return ht, yt_hat

# %% [markdown]
# Testing for just one embedding input

# %%
ht, yt_hat = stepForward(embeddings[0], Wx, Wh, Wy, h0)

# %%
ht.shape
# Out:
# torch.Size([50, 1])

# %%
yt_hat.shape
# Out:
# torch.Size([80, 1])

# %%
yt_hat.sum()
# Out:
# tensor(1., dtype=torch.float64, grad_fn=<SumBackward0>)

# %%
def full_forward_RNN(X, Wx, Wh, Wy, prev_memory):
  y_hat = []
  for t in range(len(X)): #X is the list of embeddings
    ht, yt_hat = stepForward(X[t], Wx, Wh, Wy, prev_memory)
    prev_memory = ht
    y_hat.append(yt_hat)
  return y_hat

# %%
y_hat = full_forward_RNN(embeddings, Wx, Wh, Wy, h0)

# %%
len(y_hat)
# Out:
# 5

# %%
y_hat[0].shape
# Out:
# torch.Size([80, 1])

# %%
def compute_loss(y, y_hat):
  loss = 0
  for yi, yi_hat in zip(y, y_hat):
    Li = -torch.log2(yi_hat[yi == 1])
    loss += Li
  return loss / len(y)

# %%
y = list()
for idx in output_string:
  y.append(get_one_hot(idx))

# %%
print(compute_loss(y, y_hat))
# Out:
# tensor([9.4092], dtype=torch.float64, grad_fn=<DivBackward0>)

# %%
def update_params(Wx, Wh, Wy, dWx, dWh, dWy, lr):
  with torch.no_grad():
    Wx -= lr * dWx
    Wh -= lr * dWh
    Wy -= lr * dWy

  return Wx, Wh, Wy

# %%
def train_RNN(X, y, Wx, Wh, Wy, prev_memory, lr, n_epochs):
  losses = []
  for epoch in range(n_epochs):
    y_hat = full_forward_RNN(X, Wx, Wh, Wy, prev_memory)
    loss = compute_loss(y, y_hat)
    loss.backward()
    losses.append(loss)
    print("Loss after epoch=%d: %f" %(epoch, loss))
    sys.stdout.flush()
    dWx = Wx.grad.data
    dWh = Wh.grad.data
    dWy = Wy.grad.data
    Wx, Wh, Wy = update_params(Wx, Wh, Wy, dWx, dWh, dWy, lr)
    Wx.grad.data.zero_()
    Wh.grad.data.zero_()
    Wy.grad.data.zero_()

  return Wx, Wh, Wy, losses

# %%
Wx, Wh, Wy, losses = train_RNN(embeddings, y, Wx, Wh, Wy, h0, 0.001, 100)
# Out:
# Loss after epoch=0: 9.409180
# Loss after epoch=1: 9.378634
# Loss after epoch=2: 9.348218
# Loss after epoch=3: 9.317933
# Loss after epoch=4: 9.287780
# Loss after epoch=5: 9.257760
# Loss after epoch=6: 9.227871
# Loss after epoch=7: 9.198115
# Loss after epoch=8: 9.168489
# Loss after epoch=9: 9.138993
# Loss after epoch=10: 9.109625
# Loss after epoch=11: 9.080384
# Loss after epoch=12: 9.051267
# Loss after epoch=13: 9.022272
# Loss after epoch=14: 8.993398
# Loss after epoch=15: 8.964641
# Loss after epoch=16: 8.936000
# Loss after epoch=17: 8.907472
# Loss after epoch=18: 8.879055
# Loss after epoch=19: 8.850747
# Loss after epoch=20: 8.822544
# Loss after epoch=21: 8.794444
# Loss after epoch=22: 8.766446
# Loss after epoch=23: 8.738547
# Loss after epoch=24: 8.710744
# Loss after epoch=25: 8.683036
# Loss after epoch=26: 8.655419
# Loss after epoch=27: 8.627893
# Loss after epoch=28: 8.600455
# Loss after epoch=29: 8.573102
# Loss after epoch=30: 8.545833
# Loss after epoch=31: 8.518647
# Loss after epoch=32: 8.491540
# Loss after epoch=33: 8.464513
# Loss after epoch=34: 8.437561
# Loss after epoch=35: 8.410685
# Loss after epoch=36: 8.383882
# Loss after epoch=37: 8.357151
# Loss after epoch=38: 8.330491
# Loss after epoch=39: 8.303899
# Loss after epoch=40: 8.277375
# Loss after epoch=41: 8.250917
# Loss after epoch=42: 8.224524
# Loss after epoch=43: 8.198194
# Loss after epoch=44: 8.171927
# Loss after epoch=45: 8.145721
# Loss after epoch=46: 8.119575
# Loss after epoch=47: 8.093488
# Loss after epoch=48: 8.067459
# Loss after epoch=49: 8.041487
# Loss after epoch=50: 8.015571
# Loss after epoch=51: 7.989710
# Loss after epoch=52: 7.963903
# Loss after epoch=53: 7.938149
# Loss after epoch=54: 7.912448
# Loss after epoch=55: 7.886798
# Loss after epoch=56: 7.861199
# Loss after epoch=57: 7.835650
# Loss after epoch=58: 7.810150
# Loss after epoch=59: 7.784699
# Loss after epoch=60: 7.759295
# Loss after epoch=61: 7.733939
# Loss after epoch=62: 7.708629
# Loss after epoch=63: 7.683365
# Loss after epoch=64: 7.658147
# Loss after epoch=65: 7.632974
# Loss after epoch=66: 7.607844
# Loss after epoch=67: 7.582759
# Loss after epoch=68: 7.557716
# Loss after epoch=69: 7.532717
# Loss after epoch=70: 7.507759
# Loss after epoch=71: 7.482844
# Loss after epoch=72: 7.457969
# Loss after epoch=73: 7.433136
# Loss after epoch=74: 7.408343
# Loss after epoch=75: 7.383591
# Loss after epoch=76: 7.358878
# Loss after epoch=77: 7.334205
# Loss after epoch=78: 7.309572
# Loss after epoch=79: 7.284977
# Loss after epoch=80: 7.260421
# Loss after epoch=81: 7.235903
# Loss after epoch=82: 7.211423
# Loss after epoch=83: 7.186982
# Loss after epoch=84: 7.162578
# Loss after epoch=85: 7.138212
# Loss after epoch=86: 7.113883
# Loss after epoch=87: 7.089592
# Loss after epoch=88: 7.065338
# Loss after epoch=89: 7.041122
# Loss after epoch=90: 7.016942
# Loss after epoch=91: 6.992800
# Loss after epoch=92: 6.968694
# Loss after epoch=93: 6.944626
# Loss after epoch=94: 6.920595
# Loss after epoch=95: 6.896601
# Loss after epoch=96: 6.872644
# Loss after epoch=97: 6.848725
# Loss after epoch=98: 6.824843
# Loss after epoch=99: 6.800999
